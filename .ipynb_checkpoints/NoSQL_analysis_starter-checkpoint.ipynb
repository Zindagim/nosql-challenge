# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo["uk_food"]

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db["establishments"]

# %% [markdown]
# ## Part 3: Exploratory Analysis
#
# Unless otherwise stated, for each question:
#
# - Use `count_documents` to display the number of documents contained in the result.
# - Display the first document in the results using `pprint`.
# - Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': Decimal128('0'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756322a4c43df11f6fff78'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd

df = pd.DataFrame(list(establishments.find(query)))


# Display the number of rows in the DataFrame
print(len(df))


# Display the first 10 rows of the DataFrame
print(df.head(10))

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"$or": [{"AddressLine3": "London"},
                 {"AddressLine4": "London"}
                 ],
         "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# 1394
# {'AddressLine1': '75 Woolwich Road',
#  'AddressLine2': 'Abbey Wood',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'The Croft Day Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4645.185333904148,
#  'FHRSID': 329113,
#  'LocalAuthorityBusinessID': '03260/0075/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 0DY',
#  'RatingDate': '2019-09-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756323a4c43df11f704f51'),
#  'geocode': {'latitude': 51.482981, 'longitude': 0.136519},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329113',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
import pandas as pd
df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
print(len(df))



# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# 1394
#                         _id   FHRSID  ChangesByServerID  \
# 0  65756323a4c43df11f704f51   329113                  0
# 1  65756323a4c43df11f704f53   329114                  0
# 2  65756323a4c43df11f7050af  1402880                  0
# 3  65756323a4c43df11f70515c   975472                  0
# 4  65756323a4c43df11f70515d  1262185                  0
# 5  65756323a4c43df11f7052c7   687040                  0
# 6  65756323a4c43df11f7052eb   610394                  0
# 7  65756323a4c43df11f705335  1109051                  0
# 8  65756323a4c43df11f705358  1385124                  0
# 9  65756323a4c43df11f7053fa  1256695                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0         03260/0075/0/000                              The Croft Day Nursery
# 1         03260/2001/2/000                     Belvedere Sports & Social Club
# 2              21/00281/CP  Independent Catering Management At Dulverton P...
# 3              17/00162/CP                                  Abbey Good Coffee
# 4              20/00155/CP                            Chestnuts Kiosk Limited
# 5         03190/0014/0/000                                    Brownes Chemist
# 6         03190/0008/0/000                                       A W Foodhall
# 7              19/00026/CP                      BP Thamesmead Service Station
# 8                    14474                    Alexander McLeod Primary School
# 9              20/00134/CP                                   Lakeside Nursery
#
#                 BusinessType  BusinessTypeID        AddressLine1  \
# 0            Caring Premises               5    75 Woolwich Road
# 1          Pub/bar/nightclub            7843  101A Woolwich Road
# 2  School/college/university            7845    Dulverton School
# 3    Restaurant/Cafe/Canteen               1  Lesnes Abbey Lodge
# 4    Restaurant/Cafe/Canteen               1  Lesnes Abbey Lodge
# 5          Retailers - other            4613   14-16 Wilton Road
# 6          Retailers - other            4613       8 Wilton Road
# 7          Retailers - other            4613     Service Station
# 8  School/college/university            7845      Fuchsia Street
# 9            Caring Premises               5    Lakeside Complex
#
#        AddressLine2 AddressLine3  ...             LocalAuthorityWebSite  \
# 0        Abbey Wood       London  ...          http://www.bexley.gov.uk
# 1        Abbey Wood       London  ...          http://www.bexley.gov.uk
# 2    Dulverton Road       London  ...          http://www.bexley.gov.uk
# 3          New Road       London  ...          http://www.bexley.gov.uk
# 4          New Road       London  ...          http://www.bexley.gov.uk
# 5        Abbey Wood       London  ...          http://www.bexley.gov.uk
# 6        Abbey Wood       London  ...          http://www.bexley.gov.uk
# 7   Harrow Manorway       London  ...          http://www.bexley.gov.uk
# 8                         London  ...  http://www.royalgreenwich.gov.uk
# 9  2 Bazalgette Way       London  ...          http://www.bexley.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0     food.safety@bexley.gov.uk
# 1     food.safety@bexley.gov.uk
# 2     food.safety@bexley.gov.uk
# 3     food.safety@bexley.gov.uk
# 4     food.safety@bexley.gov.uk
# 5     food.safety@bexley.gov.uk
# 6     food.safety@bexley.gov.uk
# 7     food.safety@bexley.gov.uk
# 8  health@royalgreenwich.gov.uk
# 9     food.safety@bexley.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.136519, 'latitude': 51.482981}
# 1     {'longitude': 0.136518, 'latitude': 51.482981}
# 2   {'longitude': 0.0809898, 'latitude': 51.4354901}
# 3  {'longitude': 0.120351999998093, 'latitude': 5...
# 4  {'longitude': 0.120351999998093, 'latitude': 5...
# 5      {'longitude': 0.121521, 'latitude': 51.49034}
# 6     {'longitude': 0.121087, 'latitude': 51.490312}
# 7  {'longitude': 0.12143100053072, 'latitude': 51...
# 8  {'longitude': 0.113689996302128, 'latitude': 5...
# 9   {'longitude': 0.1240915, 'latitude': 51.5010668}
#
#       Distance NewRatingPending  \
# 0  4645.185334            False
# 1  4645.185370            False
# 2  4645.469911            False
# 3  4645.644355            False
# 4  4645.644355            False
# 5  4646.002131            False
# 6  4646.016925            False
# 7  4646.116317            False
# 8  4646.144905            False
# 9  4646.302081            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = establishments.find_one({"BusinessName": "Penang Flavours"})[
    "geocode"]["latitude"]
longitude = establishments.find_one({"BusinessName": "Penang Flavours"})[
    "geocode"]["longitude"]

query = {
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
    "RatingValue": 5
}
sort = [("scores.Hygiene", -1)]

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))

# Print the results
results = establishments.find(query).sort(sort).limit(5)
for result in results:
    pprint(result)
# Out:
# 146
# {'AddressLine1': '139 Woolwich Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': 'Castellanos pizza Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.78491105744,
#  'FHRSID': 1394250,
#  'LocalAuthorityBusinessID': '14606',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE10 0RJ',
#  'RatingDate': '2021-11-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756c24452666aed2496ebd'),
#  'geocode': {'latitude': 51.4863318, 'longitude': 0.0137837},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1394250',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '42 Woolwich Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': 'Amore & Sapore Pizzeria',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.779159670448,
#  'FHRSID': 1397355,
#  'LocalAuthorityBusinessID': '14633',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE10 0JU',
#  'RatingDate': '2022-02-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756c24452666aed2496eaf'),
#  'geocode': {'latitude': 51.4859488, 'longitude': 0.0135573},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1397355',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '103 - 105 Woolwich Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': "Fisherman's Inn",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.816121755544,
#  'FHRSID': 865982,
#  'LocalAuthorityBusinessID': 'PI/000199671',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE10 0RF',
#  'RatingDate': '2021-03-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756c24452666aed2496ed8'),
#  'geocode': {'latitude': 51.4862842, 'longitude': 0.0128808},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/865982',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '22 Woolwich Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': 'Pasta Evangelists',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4649.80904844762,
#  'FHRSID': 1401633,
#  'LocalAuthorityBusinessID': '14658',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE10 0JU',
#  'RatingDate': '2022-01-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756c24452666aed2496ecc'),
#  'geocode': {'latitude': 51.4860068, 'longitude': 0.0127965},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1401633',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '1A - 3 Station Crescent',
#  'AddressLine2': '',
#  'AddressLine3': 'Blackheath',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Royal Nepalese',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4649.566052257298,
#  'FHRSID': 694751,
#  'LocalAuthorityBusinessID': 'PI/000139666',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE3 7EQ',
#  'RatingDate': '2021-07-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': Decimal128('5'),
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65756c24452666aed2496deb'),
#  'geocode': {'latitude': 51.4837638, 'longitude': 0.0172057},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694751',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query).sort(sort).limit(5)))
pprint(df.head(5))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65756c24452666aed2496ebd  1394250                  0
# 1  65756c24452666aed2496eaf  1397355                  0
# 2  65756c24452666aed2496ed8   865982                  0
# 3  65756c24452666aed2496ecc  1401633                  0
# 4  65756c24452666aed2496deb   694751                  0
#
#   LocalAuthorityBusinessID             BusinessName             BusinessType  \
# 0                    14606    Castellanos pizza Ltd  Restaurant/Cafe/Canteen
# 1                    14633  Amore & Sapore Pizzeria  Restaurant/Cafe/Canteen
# 2             PI/000199671          Fisherman's Inn   Takeaway/sandwich shop
# 3                    14658        Pasta Evangelists   Takeaway/sandwich shop
# 4             PI/000139666           Royal Nepalese  Restaurant/Cafe/Canteen
#
#    BusinessTypeID             AddressLine1 AddressLine2 AddressLine3  ...  \
# 0               1        139 Woolwich Road                 Greenwich  ...
# 1               1         42 Woolwich Road                 Greenwich  ...
# 2            7844  103 - 105 Woolwich Road                 Greenwich  ...
# 3            7844         22 Woolwich Road                 Greenwich  ...
# 4               1  1A - 3 Station Crescent                Blackheath  ...
#
#               LocalAuthorityWebSite    LocalAuthorityEmailAddress  \
# 0  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 1  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 2  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 3  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
# 4  http://www.royalgreenwich.gov.uk  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                             geocode RightToReply     Distance  \
# 0  {'longitude': 0.0137837, 'latitude': 51.4863318}               4649.784911
# 1  {'longitude': 0.0135573, 'latitude': 51.4859488}               4649.779160
# 2  {'longitude': 0.0128808, 'latitude': 51.4862842}               4649.816122
# 3  {'longitude': 0.0127965, 'latitude': 51.4860068}               4649.809048
# 4  {'longitude': 0.0172057, 'latitude': 51.4837638}               4649.566052
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
]

# Execute the aggregation pipeline
result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents in the result:", len(result))

# Print the first 10 results
print("Results:")
for i in range(min(10, len(result))):
    print(result[i])
# Out:
# Number of documents in the result: 55
# Results:
# {'_id': 'Ashford', 'count': 427}
# {'_id': 'Rother', 'count': 80}
# {'_id': 'Epping Forest', 'count': 180}
# {'_id': 'Reading', 'count': 1}
# {'_id': 'Waltham Forest', 'count': 110}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Folkestone and Hythe', 'count': 480}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Dorset', 'count': 1}
# {'_id': 'Lewisham', 'count': 65}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(len(df))

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# 55
#                     _id  count
# 0               Ashford    427
# 1                Rother     80
# 2         Epping Forest    180
# 3               Reading      1
# 4        Waltham Forest    110
# 5                Medway    672
# 6  Folkestone and Hythe    480
# 7             Greenwich    882
# 8                Dorset      1
# 9              Lewisham     65
